# %%
# !pip install pymongo
# !pip install dotenv
# !pip install chromadb
# !pip install -U sentence-transformers
# Out:
# Requirement already satisfied: pymongo in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (4.13.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from pymongo) (2.7.0)
# Requirement already satisfied: dotenv in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (0.9.9)
# Requirement already satisfied: python-dotenv in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from dotenv) (1.1.0)
# Requirement already satisfied: chromadb in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (1.0.9)
# Requirement already satisfied: build>=1.0.3 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from chromadb) (2.10.1)
# Requirement already satisfied: fastapi==0.115.9 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from chromadb) (0.115.9)
# Requirement already satisfied: uvicorn>=0.18.3 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.34.2)
# Requirement already satisfied: numpy>=1.22.5 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from chromadb) (4.0.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from chromadb) (4.13.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from chromadb) (1.19.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from chromadb) (1.33.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from chromadb) (1.33.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from chromadb) (0.54b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from chromadb) (1.33.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from chromadb) (0.21.1)
# Requirement already satisfied: pypika>=0.48.9 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from chromadb) (1.71.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from chromadb) (0.15.4)
# Requirement already satisfied: kubernetes>=28.1.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from chromadb) (32.0.1)
# Requirement already satisfied: tenacity>=8.2.3 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from chromadb) (6.0)
# Requirement already satisfied: mmh3>=4.0.1 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from chromadb) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from chromadb) (3.10.14)
# Requirement already satisfied: httpx>=0.27.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from chromadb) (14.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from chromadb) (4.23.0)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from fastapi==0.115.9->chromadb) (0.45.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from pydantic>=1.9->chromadb) (2.27.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from starlette<0.46.0,>=0.40.0->fastapi==0.115.9->chromadb) (3.7.1)
# Requirement already satisfied: idna>=2.8 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from anyio<5,>=3.6.2->starlette<0.46.0,>=0.40.0->fastapi==0.115.9->chromadb) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from anyio<5,>=3.6.2->starlette<0.46.0,>=0.40.0->fastapi==0.115.9->chromadb) (1.3.1)
# Requirement already satisfied: exceptiongroup in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from anyio<5,>=3.6.2->starlette<0.46.0,>=0.40.0->fastapi==0.115.9->chromadb) (1.2.2)
# Requirement already satisfied: packaging>=19.1 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (24.2)
# Requirement already satisfied: pyproject_hooks in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: importlib-metadata>=4.6 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (8.6.1)
# Requirement already satisfied: tomli>=1.1.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (2.2.1)
# Requirement already satisfied: certifi in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: zipp>=3.20 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from importlib-metadata>=4.6->build>=1.0.3->chromadb) (3.21.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from jsonschema>=4.19.0->chromadb) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from jsonschema>=4.19.0->chromadb) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from jsonschema>=4.19.0->chromadb) (0.22.3)
# Requirement already satisfied: six>=1.9.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.40.1)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.32.3)
# Requirement already satisfied: requests-oauthlib in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (1.26.15)
# Requirement already satisfied: durationpy>=0.7 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (0.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Requirement already satisfied: coloredlogs in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: protobuf in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.3)
# Requirement already satisfied: sympy in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: deprecated>=1.2.6 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.18)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.2.0->chromadb) (1.17.2)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.33.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.33.0)
# Requirement already satisfied: opentelemetry-proto==1.33.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.33.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.54b0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.54b0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.54b0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.54b0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b0)
# Requirement already satisfied: opentelemetry-util-http==0.54b0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b0)
# Requirement already satisfied: asgiref~=3.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from opentelemetry-instrumentation-asgi==0.54b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: backoff>=1.10.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.3.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from tokenizers>=0.13.2->chromadb) (0.31.2)
# Requirement already satisfied: filelock in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.3.2)
# Requirement already satisfied: click<8.2,>=8.0.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from typer>=0.9.0->chromadb) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.0)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.5)
# Requirement already satisfied: websockets>=10.4 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Collecting sentence_transformers
#   Downloading sentence_transformers-4.1.0-py3-none-any.whl.metadata (13 kB)
# Collecting transformers<5.0.0,>=4.41.0 (from sentence_transformers)
#   Downloading transformers-4.51.3-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: tqdm in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from sentence_transformers) (4.67.1)
# Collecting torch>=1.11.0 (from sentence_transformers)
#   Downloading torch-2.7.0-cp39-cp39-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Collecting scikit-learn (from sentence_transformers)
#   Downloading scikit_learn-1.6.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: scipy in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from sentence_transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from sentence_transformers) (0.31.2)
# Requirement already satisfied: Pillow in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from sentence_transformers) (11.1.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from sentence_transformers) (4.13.2)
# Requirement already satisfied: filelock in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2024.11.6)
# Requirement already satisfied: requests in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.21.1)
# Collecting safetensors>=0.4.3 (from transformers<5.0.0,>=4.41.0->sentence_transformers)
#   Downloading safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2025.3.2)
# Requirement already satisfied: sympy>=1.13.3 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from torch>=1.11.0->sentence_transformers) (1.14.0)
# Collecting networkx (from torch>=1.11.0->sentence_transformers)
#   Downloading networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: jinja2 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from torch>=1.11.0->sentence_transformers) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.26.2 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufile-cu12==1.11.1.6 (from torch>=1.11.0->sentence_transformers)
#   Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.3.0 (from torch>=1.11.0->sentence_transformers)
#   Downloading triton-3.3.0-cp39-cp39-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: setuptools>=40.8.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from triton==3.3.0->torch>=1.11.0->sentence_transformers) (80.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence_transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from jinja2->torch>=1.11.0->sentence_transformers) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence_transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence_transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence_transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence_transformers) (2025.4.26)
# Collecting joblib>=1.2.0 (from scikit-learn->sentence_transformers)
#   Downloading joblib-1.5.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->sentence_transformers)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading sentence_transformers-4.1.0-py3-none-any.whl (345 kB)
# Downloading transformers-4.51.3-py3-none-any.whl (10.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/10.4 MB ? eta -:--:--0m
# WARNING: Connection timed out while downloading.
# error: incomplete-download
#
# × Download failed because not enough bytes were received (0 bytes/10.4 MB)
# ╰─> URL: https://files.pythonhosted.org/packages/a9/b6/5257d04ae327b44db31f15cce39e6020cc986333c715660b1315a9724d82/transformers-4.51.3-py3-none-any.whl
#
# note: This is an issue with network connectivity, not pip.
# hint: Consider using --resume-retries to enable download resumption.

# %%
import os
import uuid
from datetime import datetime
from typing import List, Dict

import chromadb
from chromadb.utils import embedding_functions
from langchain_core.prompts import ChatPromptTemplate
from langchain_ollama import OllamaLLM
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_core.documents import Document
from langchain_ollama import OllamaEmbeddings
from langchain.vectorstores import Chroma
from pymongo import MongoClient
from dotenv import load_dotenv

# %%
load_dotenv()
class MongoConnectionHandler:
    def __init__ (self):
        self.client = MongoClient(os.getenv('MONGO_URL'))
        self.db=self.client.get_database(os.getenv('MONGO_DB'))
    
    def get_related_documents(self) -> List[Dict]:
        orders = list(self.db.orders.find())
        client_ids = [order['orderCreatedBy'] for order in orders]
        item_ids = [item_id for order in orders for item_id in order['orderItems']]
        
        """ GET CLIENTS AND ORDER ITEMS """
        clients = {str(c['_id']) : c for c in self.db.clients.find({'_id': {'$in': client_ids}})}
        items = {str(i['_id']) : i for i in self.db.order_items.find({'_id': {'$in': item_ids}})}

        combined_orders = []
        for order in orders:
            client = clients.get(str(order['orderCreatedBy']))
            order_items = [items[str(item_id)] for item_id in order['orderItems'] if str(item_id) in items]

            if client and order_items:
                combined_orders.append({
                    "order": order,
                    "client": client,
                    "items": order_items
                })
        return combined_orders
# Out:
# python-dotenv could not parse statement starting at line 1
# python-dotenv could not parse statement starting at line 7

# %%
class DocumentProcessor:
    
    def create_chunks(self, data: List[Dict]) -> List[Dict]:
        return [self._create_order_chunk(rec["order"], rec["client"], rec["items"]) for rec in data]

    def _create_order_chunk(self, order: Dict, client: Dict, items: List[Dict]) -> Dict:
        chunk_text = f"""
        [Order {order['_id']}] = 
        Status: "{order.get('status', 'N/A')}" ,
        Created Date: "{self._format_date(order.get('createdAt'))}" ,
        Contract: "{order.get('orderContractType', 'N/A')}" |
        
        [Client {client['_id']}] =
        Company: "{client.get('legalNameOfCompany', 'N/A')}" ,
        Client Name: "{client.get('contactFirstName', '')} {client.get('contactLastName', '')}" ,
        Email: "{client.get('contactEmail', 'N/A')}" ,
        Company Address: "{client.get('physicalAddressOfCompany', {}).get("address", "")}"
        Company City: "{client.get('physicalAddressOfCompany', {}).get("city", "")}"
        Preferences: ({', '.join(client.get('preferredCoffeeTypes', []))}) |
        
        [Items] = 
        {self._format_items(items)}
        """
        
        return {
            "text": self._clean_text(chunk_text),
            "metadata": {
                "order_id": str(order["_id"]),
                "client_id": str(client["_id"]),
                "status": order.get("status", "UNKNOWN"),
                "total_value": sum(item.get("price", 0) * item.get("totalAmount", 0) for item in items),
                "creation_date": str(order.get("createdAt", "")),
                "client_name": client.get("ownersFirstName", "") + " " + client.get("ownersLastName", "")
                 # "coffee_types": client.get("preferredCoffeeTypes", [])
            }
        }

    def _format_items(self, items: List[Dict]) -> str:
        return '\n'.join([
            f"Item {idx + 1} ID: \"{item.get('r_id', 'N/A')}\" , "
            f"Total Amount: \"{item.get('totalAmount', 0)}lbs\" , "
            f"Price: \"${item.get('price', 0)}\" , "
            f"Status: \"{item.get('status', 'N/A')}\" , "
            f"Last Updated: \"{self._format_date(item.get('updatedAt'))}\","
            for idx, item in enumerate(items)
        ])

    def _clean_text(self, text: str) -> str:
        return ' '.join(text.strip().split())

    def _format_date(self, date_str: str) -> str:
        try:
            return datetime.fromisoformat(date_str.replace('Z', '')).strftime("%Y-%m-%d %H:%M")
        except:
            return "Date not available"

# %%
data = MongoConnectionHandler().get_related_documents()
# data
processor = DocumentProcessor()
chunks = processor.create_chunks(data)
chunks
# Out:
# [{'text': '[Order 65cdf655acb24b003b673350] = Status: "CANCELLED" , Created Date: "Date not available" , Contract: "N/A" | [Client 65c22c47b062b6003c932497] = Company: "Cafe Kreyol, LLC" , Client Name: "Joseph Stazzone" , Email: "joey@cafekreyol.com" , Company Address: "10439 Balls Ford Road" Company City: "Manassas" Preferences: (Natural, Washed, Honey, Anerobic, Carbonic Maceration) | [Items] = Item 1 ID: "1-OrdIt1" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 2 ID: "1-OrdIt5" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 3 ID: "1-OrdIt4" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 4 ID: "1-OrdIt3" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 5 ID: "1-OrdIt0" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 6 ID: "1-OrdIt2" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available",',
#   'metadata': {'order_id': '65cdf655acb24b003b673350',
#    'client_id': '65c22c47b062b6003c932497',
#    'status': 'CANCELLED',
#    'total_value': 0,
#    'creation_date': '2024-02-15 11:32:37.560000',
#    'client_name': 'Joseph Stazzone'}},
#  {'text': '[Order 65d238d4acb24b003b6733a4] = Status: "CANCELLED" , Created Date: "Date not available" , Contract: "N/A" | [Client 65c22c47b062b6003c932497] = Company: "Cafe Kreyol, LLC" , Client Name: "Joseph Stazzone" , Email: "joey@cafekreyol.com" , Company Address: "10439 Balls Ford Road" Company City: "Manassas" Preferences: (Natural, Washed, Honey, Anerobic, Carbonic Maceration) | [Items] = Item 1 ID: "2-OrdIt1" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 2 ID: "2-OrdIt0" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 3 ID: "2-OrdIt2" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available",',
#   'metadata': {'order_id': '65d238d4acb24b003b6733a4',
#    'client_id': '65c22c47b062b6003c932497',
#    'status': 'CANCELLED',
#    'total_value': 0,
#    'creation_date': '2024-02-18 17:05:25.107000',
#    'client_name': 'Joseph Stazzone'}},
#  {'text': '[Order 65d4699a23689a0065747b90] = Status: "CANCELLED" , Created Date: "Date not available" , Contract: "N/A" | [Client 65c22c47b062b6003c932497] = Company: "Cafe Kreyol, LLC" , Client Name: "Joseph Stazzone" , Email: "joey@cafekreyol.com" , Company Address: "10439 Balls Ford Road" Company City: "Manassas" Preferences: (Natural, Washed, Honey, Anerobic, Carbonic Maceration) | [Items] = Item 1 ID: "3-OrdIt1" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 2 ID: "3-OrdIt0" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 3 ID: "3-OrdIt3" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 4 ID: "3-OrdIt5" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 5 ID: "3-OrdIt7" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 6 ID: "3-OrdIt2" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 7 ID: "3-OrdIt8" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 8 ID: "3-OrdIt6" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 9 ID: "3-OrdIt4" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 10 ID: "3-OrdIt9" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available",',
#   'metadata': {'order_id': '65d4699a23689a0065747b90',
#    'client_id': '65c22c47b062b6003c932497',
#    'status': 'CANCELLED',
#    'total_value': 0,
#    'creation_date': '2024-02-20 08:58:03.963000',
#    'client_name': 'Joseph Stazzone'}},
#  {'text': '[Order 65dccb67aef560003b964db0] = Status: "CANCELLED" , Created Date: "Date not available" , Contract: "N/A" | [Client 6599062b301a910033c11467] = Company: "More Coffee" , Client Name: "Tom Gelson" , Email: "tgelson15@gmail.com" , Company Address: "11220 Valor Bridge Drive" Company City: "Spotsylvania Courthouse" Preferences: (Washed) | [Items] = Item 1 ID: "4-OrdIt0" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 2 ID: "4-OrdIt1" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 3 ID: "4-OrdIt2" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 4 ID: "4-OrdIt3" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available",',
#   'metadata': {'order_id': '65dccb67aef560003b964db0',
#    'client_id': '6599062b301a910033c11467',
#    'status': 'CANCELLED',
#    'total_value': 0,
#    'creation_date': '2024-02-26 17:33:27.880000',
#    'client_name': 'Thomas Gelson'}},
#  {'text': '[Order 65ddf837aef560003b96616f] = Status: "COMPLETED" , Created Date: "Date not available" , Contract: "From Farmer" | [Client 65ccb04c158734003c880412] = Company: "Right Side Coffee SL" , Client Name: "Joaquin Parra" , Email: "joaquin@rightsidecoffee.com" , Company Address: "Castelldefels, Spain" Company City: "Castelldefels" Preferences: (Natural, Washed, Honey, Anerobic) | [Items] = Item 1 ID: "5-OrdIt8" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 2 ID: "5-OrdIt0" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 3 ID: "5-OrdIt2" , Total Amount: "20lbs" , Price: "$3.9" , Status: "ACCEPTED" , Last Updated: "Date not available", Item 4 ID: "5-OrdIt1" , Total Amount: "20lbs" , Price: "$4" , Status: "ACCEPTED" , Last Updated: "Date not available", Item 5 ID: "5-OrdIt4" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 6 ID: "5-OrdIt3" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 7 ID: "5-OrdIt6" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 8 ID: "5-OrdIt7" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 9 ID: "5-OrdIt9" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 10 ID: "5-OrdIt10" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 11 ID: "5-OrdIt11" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 12 ID: "5-OrdIt5" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available",',
#   'metadata': {'order_id': '65ddf837aef560003b96616f',
#    'client_id': '65ccb04c158734003c880412',
#    'status': 'COMPLETED',
#    'total_value': 158.0,
#    'creation_date': '2024-02-27 14:56:56.044000',
#    'client_name': 'Joaquin Parra Serrano'}},
#  {'text': '[Order 65f5809d67bdac001ddd0129] = Status: "COMPLETED" , Created Date: "Date not available" , Contract: "From Farmer" | [Client 65c22c47b062b6003c932497] = Company: "Cafe Kreyol, LLC" , Client Name: "Joseph Stazzone" , Email: "joey@cafekreyol.com" , Company Address: "10439 Balls Ford Road" Company City: "Manassas" Preferences: (Natural, Washed, Honey, Anerobic, Carbonic Maceration) | [Items] = Item 1 ID: "6-OrdIt0" , Total Amount: "45lbs" , Price: "$4" , Status: "ACCEPTED" , Last Updated: "Date not available", Item 2 ID: "6-OrdIt1" , Total Amount: "65lbs" , Price: "$4" , Status: "REJECTED" , Last Updated: "Date not available",',
#   'metadata': {'order_id': '65f5809d67bdac001ddd0129',
#    'client_id': '65c22c47b062b6003c932497',
#    'status': 'COMPLETED',
#    'total_value': 440,
#    'creation_date': '2024-03-16 11:21:02.184000',
#    'client_name': 'Joseph Stazzone'}},
#  {'text': '[Order 662fad1c9f875700331671db] = Status: "CANCELLED" , Created Date: "Date not available" , Contract: "From Farmer" | [Client 659e1eac301a910033c11d1d] = Company: "sprl cafermi" , Client Name: "Miguel Arnould " , Email: "info@cafermi.be" , Company Address: "Rue de Bouillon, Bièvre, Belgium" Company City: "Bièvre" Preferences: (Natural) | [Items] = Item 1 ID: "7-OrdIt6" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 2 ID: "7-OrdIt0" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 3 ID: "7-OrdIt2" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 4 ID: "7-OrdIt3" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 5 ID: "7-OrdIt4" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 6 ID: "7-OrdIt5" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 7 ID: "7-OrdIt7" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 8 ID: "7-OrdIt8" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 9 ID: "7-OrdIt1" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available",',
#   'metadata': {'order_id': '662fad1c9f875700331671db',
#    'client_id': '659e1eac301a910033c11d1d',
#    'status': 'CANCELLED',
#    'total_value': 0,
#    'creation_date': '2024-04-29 14:22:21.205000',
#    'client_name': 'miguel arnould'}},
#  {'text': '[Order 6642373a3e64e8001e72acbd] = Status: "COMPLETED" , Created Date: "Date not available" , Contract: "From Farmer" | [Client 65c22c47b062b6003c932497] = Company: "Cafe Kreyol, LLC" , Client Name: "Joseph Stazzone" , Email: "joey@cafekreyol.com" , Company Address: "10439 Balls Ford Road" Company City: "Manassas" Preferences: (Natural, Washed, Honey, Anerobic, Carbonic Maceration) | [Items] = Item 1 ID: "8-OrdIt0" , Total Amount: "20lbs" , Price: "$3" , Status: "ACCEPTED" , Last Updated: "Date not available", Item 2 ID: "8-OrdIt1" , Total Amount: "48lbs" , Price: "$3.9" , Status: "ACCEPTED" , Last Updated: "Date not available",',
#   'metadata': {'order_id': '6642373a3e64e8001e72acbd',
#    'client_id': '65c22c47b062b6003c932497',
#    'status': 'COMPLETED',
#    'total_value': 247.2,
#    'creation_date': '2024-05-13 15:52:26.581000',
#    'client_name': 'Joseph Stazzone'}},
#  {'text': '[Order 67c17eba3ad54c001c8f071a] = Status: "PROCESSING" , Created Date: "Date not available" , Contract: "N/A" | [Client 65c22c47b062b6003c932497] = Company: "Cafe Kreyol, LLC" , Client Name: "Joseph Stazzone" , Email: "joey@cafekreyol.com" , Company Address: "10439 Balls Ford Road" Company City: "Manassas" Preferences: (Natural, Washed, Honey, Anerobic, Carbonic Maceration) | [Items] = Item 1 ID: "11-OrdIt0" , Total Amount: "0lbs" , Price: "$0" , Status: "PROCESSING" , Last Updated: "Date not available", Item 2 ID: "11-OrdIt1" , Total Amount: "0lbs" , Price: "$0" , Status: "PROCESSING" , Last Updated: "Date not available", Item 3 ID: "11-OrdIt2" , Total Amount: "0lbs" , Price: "$0" , Status: "PROCESSING" , Last Updated: "Date not available", Item 4 ID: "11-OrdIt3" , Total Amount: "0lbs" , Price: "$0" , Status: "PROCESSING" , Last Updated: "Date not available", Item 5 ID: "11-OrdIt4" , Total Amount: "0lbs" , Price: "$0" , Status: "PROCESSING" , Last Updated: "Date not available", Item 6 ID: "11-OrdIt5" , Total Amount: "0lbs" , Price: "$0" , Status: "PROCESSING" , Last Updated: "Date not available", Item 7 ID: "11-OrdIt7" , Total Amount: "0lbs" , Price: "$0" , Status: "PROCESSING" , Last Updated: "Date not available", Item 8 ID: "11-OrdIt8" , Total Amount: "0lbs" , Price: "$0" , Status: "PROCESSING" , Last Updated: "Date not available", Item 9 ID: "11-OrdIt6" , Total Amount: "0lbs" , Price: "$0" , Status: "PROCESSING" , Last Updated: "Date not available", Item 10 ID: "11-OrdIt11" , Total Amount: "0lbs" , Price: "$0" , Status: "PROCESSING" , Last Updated: "Date not available", Item 11 ID: "11-OrdIt12" , Total Amount: "0lbs" , Price: "$0" , Status: "PROCESSING" , Last Updated: "Date not available", Item 12 ID: "11-OrdIt13" , Total Amount: "0lbs" , Price: "$0" , Status: "PROCESSING" , Last Updated: "Date not available", Item 13 ID: "11-OrdIt10" , Total Amount: "0lbs" , Price: "$0" , Status: "PROCESSING" , Last Updated: "Date not available", Item 14 ID: "11-OrdIt14" , Total Amount: "0lbs" , Price: "$0" , Status: "PROCESSING" , Last Updated: "Date not available", Item 15 ID: "11-OrdIt15" , Total Amount: "0lbs" , Price: "$0" , Status: "PROCESSING" , Last Updated: "Date not available", Item 16 ID: "11-OrdIt16" , Total Amount: "0lbs" , Price: "$0" , Status: "PROCESSING" , Last Updated: "Date not available", Item 17 ID: "11-OrdIt17" , Total Amount: "0lbs" , Price: "$0" , Status: "PROCESSING" , Last Updated: "Date not available", Item 18 ID: "11-OrdIt9" , Total Amount: "0lbs" , Price: "$0" , Status: "PROCESSING" , Last Updated: "Date not available",',
#   'metadata': {'order_id': '67c17eba3ad54c001c8f071a',
#    'client_id': '65c22c47b062b6003c932497',
#    'status': 'PROCESSING',
#    'total_value': 0,
#    'creation_date': '2025-02-28 09:15:39.333000',
#    'client_name': 'Joseph Stazzone'}},
#  {'text': '[Order 67c04f18074f4300344156ce] = Status: "PROCESSING" , Created Date: "Date not available" , Contract: "N/A" | [Client 65ccb04c158734003c880412] = Company: "Right Side Coffee SL" , Client Name: "Joaquin Parra" , Email: "joaquin@rightsidecoffee.com" , Company Address: "Castelldefels, Spain" Company City: "Castelldefels" Preferences: (Natural, Washed, Honey, Anerobic) | [Items] = Item 1 ID: "9-OrdIt0" , Total Amount: "0lbs" , Price: "$0" , Status: "PENDING" , Last Updated: "Date not available", Item 2 ID: "9-OrdIt1" , Total Amount: "0lbs" , Price: "$0" , Status: "PROCESSING" , Last Updated: "Date not available",',
#   'metadata': {'order_id': '67c04f18074f4300344156ce',
#    'client_id': '65ccb04c158734003c880412',
#    'status': 'PROCESSING',
#    'total_value': 0,
#    'creation_date': '2025-02-27 11:40:08.858000',
#    'client_name': 'Joaquin Parra Serrano'}},
#  {'text': '[Order 67e383f9c0c2422dd6420df5] = Status: "CANCELLED" , Created Date: "Date not available" , Contract: "From Farmer" | [Client 65a6288ddf1668003bbe3354] = Company: "Addissoftware" , Client Name: "Leul Habte" , Email: "leulh63@gmail.com" , Company Address: "Fildişi Sahili" Company City: "Plat" Preferences: (Other) | [Items] = Item 1 ID: "12-OrdIt0" , Total Amount: "0lbs" , Price: "$3" , Status: "REJECTED" , Last Updated: "Date not available",',
#   'metadata': {'order_id': '67e383f9c0c2422dd6420df5',
#    'client_id': '65a6288ddf1668003bbe3354',
#    'status': 'CANCELLED',
#    'total_value': 0,
#    'creation_date': '2025-03-26 04:35:05.286000',
#    'client_name': 'Leul Habte'}},
#  {'text': '[Order 67f891a32a26ac30a3e47d1e] = Status: "PROCESSING" , Created Date: "Date not available" , Contract: "From Farmer" | [Client 65a6288ddf1668003bbe3354] = Company: "Addissoftware" , Client Name: "Leul Habte" , Email: "leulh63@gmail.com" , Company Address: "Fildişi Sahili" Company City: "Plat" Preferences: (Other) | [Items] = Item 1 ID: "13-OrdIt0" , Total Amount: "80lbs" , Price: "$3.5" , Status: "ACCEPTED" , Last Updated: "Date not available",',
#   'metadata': {'order_id': '67f891a32a26ac30a3e47d1e',
#    'client_id': '65a6288ddf1668003bbe3354',
#    'status': 'PROCESSING',
#    'total_value': 280.0,
#    'creation_date': '2025-04-11 03:51:00.068000',
#    'client_name': 'Leul Habte'}},
#  {'text': '[Order 67f91ba7519c95a6bdd8a7ec] = Status: "COMPLETED" , Created Date: "Date not available" , Contract: "From Farmer" | [Client 65a6288ddf1668003bbe3354] = Company: "Addissoftware" , Client Name: "Leul Habte" , Email: "leulh63@gmail.com" , Company Address: "Fildişi Sahili" Company City: "Plat" Preferences: (Other) | [Items] = Item 1 ID: "14-OrdIt0" , Total Amount: "20lbs" , Price: "$4.5" , Status: "ACCEPTED" , Last Updated: "Date not available",',
#   'metadata': {'order_id': '67f91ba7519c95a6bdd8a7ec',
#    'client_id': '65a6288ddf1668003bbe3354',
#    'status': 'COMPLETED',
#    'total_value': 90.0,
#    'creation_date': '2025-04-11 13:39:51.841000',
#    'client_name': 'Leul Habte'}},
#  {'text': '[Order 67fcab4f455a577fb3ee3765] = Status: "PROCESSING" , Created Date: "Date not available" , Contract: "From Arkena" | [Client 65a6288ddf1668003bbe3354] = Company: "Addissoftware" , Client Name: "Leul Habte" , Email: "leulh63@gmail.com" , Company Address: "Fildişi Sahili" Company City: "Plat" Preferences: (Other) | [Items] = Item 1 ID: "15-OrdIt0" , Total Amount: "20lbs" , Price: "$5" , Status: "ACCEPTED" , Last Updated: "Date not available",',
#   'metadata': {'order_id': '67fcab4f455a577fb3ee3765',
#    'client_id': '65a6288ddf1668003bbe3354',
#    'status': 'PROCESSING',
#    'total_value': 100,
#    'creation_date': '2025-04-14 06:29:35.593000',
#    'client_name': 'Leul Habte'}},
#  {'text': '[Order 67fcbb158c01970d0b2427af] = Status: "PENDING" , Created Date: "Date not available" , Contract: "N/A" | [Client 65a6288ddf1668003bbe3354] = Company: "Addissoftware" , Client Name: "Leul Habte" , Email: "leulh63@gmail.com" , Company Address: "Fildişi Sahili" Company City: "Plat" Preferences: (Other) | [Items] = Item 1 ID: "16-OrdIt0" , Total Amount: "0lbs" , Price: "$0" , Status: "PENDING" , Last Updated: "Date not available",',
#   'metadata': {'order_id': '67fcbb158c01970d0b2427af',
#    'client_id': '65a6288ddf1668003bbe3354',
#    'status': 'PENDING',
#    'total_value': 0,
#    'creation_date': '2025-04-14 07:36:53.203000',
#    'client_name': 'Leul Habte'}},
#  {'text': '[Order 67fcc4afdf849223828929b4] = Status: "PROCESSING" , Created Date: "Date not available" , Contract: "From Farmer" | [Client 65a6288ddf1668003bbe3354] = Company: "Addissoftware" , Client Name: "Leul Habte" , Email: "leulh63@gmail.com" , Company Address: "Fildişi Sahili" Company City: "Plat" Preferences: (Other) | [Items] = Item 1 ID: "17-OrdIt0" , Total Amount: "20lbs" , Price: "$2" , Status: "PROCESSING" , Last Updated: "Date not available",',
#   'metadata': {'order_id': '67fcc4afdf849223828929b4',
#    'client_id': '65a6288ddf1668003bbe3354',
#    'status': 'PROCESSING',
#    'total_value': 40,
#    'creation_date': '2025-04-14 08:17:51.470000',
#    'client_name': 'Leul Habte'}},
#  {'text': '[Order 67fcef44a7a85f5d2da18d90] = Status: "PROCESSING" , Created Date: "Date not available" , Contract: "From Arkena" | [Client 65a6288ddf1668003bbe3354] = Company: "Addissoftware" , Client Name: "Leul Habte" , Email: "leulh63@gmail.com" , Company Address: "Fildişi Sahili" Company City: "Plat" Preferences: (Other) | [Items] = Item 1 ID: "18-OrdIt0" , Total Amount: "0lbs" , Price: "$0" , Status: "PROCESSING" , Last Updated: "Date not available", Item 2 ID: "18-OrdIt20" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available",',
#   'metadata': {'order_id': '67fcef44a7a85f5d2da18d90',
#    'client_id': '65a6288ddf1668003bbe3354',
#    'status': 'PROCESSING',
#    'total_value': 0,
#    'creation_date': '2025-04-14 11:19:32.550000',
#    'client_name': 'Leul Habte'}},
#  {'text': '[Order 67fdfdae4f79317e0156b836] = Status: "COMPLETED" , Created Date: "Date not available" , Contract: "From Arkena" | [Client 65a6288ddf1668003bbe3354] = Company: "Addissoftware" , Client Name: "Leul Habte" , Email: "leulh63@gmail.com" , Company Address: "Fildişi Sahili" Company City: "Plat" Preferences: (Other) | [Items] = Item 1 ID: "19-OrdIt0" , Total Amount: "20lbs" , Price: "$3" , Status: "ACCEPTED" , Last Updated: "Date not available",',
#   'metadata': {'order_id': '67fdfdae4f79317e0156b836',
#    'client_id': '65a6288ddf1668003bbe3354',
#    'status': 'COMPLETED',
#    'total_value': 60,
#    'creation_date': '2025-04-15 06:33:18.810000',
#    'client_name': 'Leul Habte'}},
#  {'text': '[Order 67fe1732effef122212a514a] = Status: "PROCESSING" , Created Date: "Date not available" , Contract: "From Farmer" | [Client 65a6288ddf1668003bbe3354] = Company: "Addissoftware" , Client Name: "Leul Habte" , Email: "leulh63@gmail.com" , Company Address: "Fildişi Sahili" Company City: "Plat" Preferences: (Other) | [Items] = Item 1 ID: "20-OrdIt0" , Total Amount: "0lbs" , Price: "$0" , Status: "PROCESSING" , Last Updated: "Date not available",',
#   'metadata': {'order_id': '67fe1732effef122212a514a',
#    'client_id': '65a6288ddf1668003bbe3354',
#    'status': 'PROCESSING',
#    'total_value': 0,
#    'creation_date': '2025-04-15 08:22:10.166000',
#    'client_name': 'Leul Habte'}},
#  {'text': '[Order 67ff3968ffa3e23536247a15] = Status: "COMPLETED" , Created Date: "Date not available" , Contract: "From Arkena" | [Client 65a6288ddf1668003bbe3354] = Company: "Addissoftware" , Client Name: "Leul Habte" , Email: "leulh63@gmail.com" , Company Address: "Fildişi Sahili" Company City: "Plat" Preferences: (Other) | [Items] = Item 1 ID: "21-OrdIt0" , Total Amount: "20lbs" , Price: "$20" , Status: "ACCEPTED" , Last Updated: "Date not available",',
#   'metadata': {'order_id': '67ff3968ffa3e23536247a15',
#    'client_id': '65a6288ddf1668003bbe3354',
#    'status': 'COMPLETED',
#    'total_value': 400,
#    'creation_date': '2025-04-16 05:00:25.042000',
#    'client_name': 'Leul Habte'}}]

# %%
class VectorStore:
    def __init__(self):
        self.embedder = embedding_functions.SentenceTransformerEmbeddingFunction(
            model_name="all-mpnet-base-v2"
        )
        self.client = chromadb.PersistentClient(path="./chroma_dbs")
        self.collection = self.client.get_or_create_collection(
            name="coffee_orders_processing",
            embedding_function=self.embedder,
            
        )
    
    def index_documents(self, chunks: List[Dict]):
        ids = [str(uuid.uuid4()) for _ in chunks]
        documents = [chunk['text'] for chunk in chunks]
        metadatas = [chunk['metadata'] for chunk in chunks]
        
        self.collection.add(
            ids=ids,
            documents=documents,
            metadatas=metadatas
        )
    
    def query(self, query: str, filters: Dict = None, n_results: int = 10) -> List[Dict]:
        results = self.collection.query(
            query_texts=[query],
            where=filters,
            n_results=n_results,
            include=["metadatas", "documents"]
        )
        return [{
            "text": doc,
            "metadata": meta
        } for doc, meta in zip(results["documents"][0], results["metadatas"][0])]

# %%
from sentence_transformers import SentenceTransformer
model=SentenceTransformer('all-mpnet-base-v2')
sentences = [
    "The weather is lovely today.",
    "It's so sunny outside!",
    "He drove to the stadium.",
]
embeddings = model.encode(sentences)
embeddings
# from chromadb.utils import embedding_functions
# df_e = embedding_functions.SentenceTransformerEmbeddingFunction(model_name='all-mpnet-base-v2')
# value = df_e(['Hello world'])
# value
# Out:
# Collecting sentence-transformers
#   Using cached sentence_transformers-4.1.0-py3-none-any.whl.metadata (13 kB)
# Collecting transformers<5.0.0,>=4.41.0 (from sentence-transformers)
#   Using cached transformers-4.51.3-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: tqdm in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from sentence-transformers) (4.67.1)
# Collecting torch>=1.11.0 (from sentence-transformers)
#   Using cached torch-2.7.0-cp39-cp39-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Collecting scikit-learn (from sentence-transformers)
#   Using cached scikit_learn-1.6.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: scipy in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from sentence-transformers) (0.31.2)
# Requirement already satisfied: Pillow in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from sentence-transformers) (11.1.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from sentence-transformers) (4.13.2)
# Requirement already satisfied: filelock in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: requests in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.1)
# Collecting safetensors>=0.4.3 (from transformers<5.0.0,>=4.41.0->sentence-transformers)
#   Using cached safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.2)
# Requirement already satisfied: sympy>=1.13.3 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Collecting networkx (from torch>=1.11.0->sentence-transformers)
#   Using cached networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: jinja2 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.26.2 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufile-cu12==1.11.1.6 (from torch>=1.11.0->sentence-transformers)
#   Using cached nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.3.0 (from torch>=1.11.0->sentence-transformers)
#   Using cached triton-3.3.0-cp39-cp39-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: setuptools>=40.8.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from triton==3.3.0->torch>=1.11.0->sentence-transformers) (80.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /home/leul/anaconda3/envs/ml_env/lib/python3.9/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.4.26)
# Collecting joblib>=1.2.0 (from scikit-learn->sentence-transformers)
#   Using cached joblib-1.5.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->sentence-transformers)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Using cached sentence_transformers-4.1.0-py3-none-any.whl (345 kB)
# Using cached transformers-4.51.3-py3-none-any.whl (10.4 MB)
# Using cached safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (471 kB)
# Downloading torch-2.7.0-cp39-cp39-manylinux_2_28_x86_64.whl (865.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 865.2/865.2 MB 16.1 MB/s eta 0:00:0000:0100:02
# Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 17.5 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 20.7 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 19.8 MB/s eta 0:00:00a 0:00:01
# Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 11.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.0/571.0 MB 17.6 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 MB 17.8 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 14.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 16.3 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 MB 17.5 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 MB 19.1 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 MB 16.9 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 17.2 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 17.3 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Downloading triton-3.3.0-cp39-cp39-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (156.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.4/156.4 MB 16.8 MB/s eta 0:00:0000:0100:01
# Downloading networkx-3.2.1-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 26.0 MB/s eta 0:00:00
# Downloading scikit_learn-1.6.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 14.5 MB/s eta 0:00:00a 0:00:01
# Downloading joblib-1.5.0-py3-none-any.whl (307 kB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: nvidia-cusparselt-cu12, triton, threadpoolctl, safetensors, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, networkx, joblib, scikit-learn, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, transformers, torch, sentence-transformers
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23/23 [sentence-transformers]ence-transformers]]
# Successfully installed joblib-1.5.0 networkx-3.2.1 nvidia-cublas-cu12-12.6.4.1 nvidia-cuda-cupti-cu12-12.6.80 nvidia-cuda-nvrtc-cu12-12.6.77 nvidia-cuda-runtime-cu12-12.6.77 nvidia-cudnn-cu12-9.5.1.17 nvidia-cufft-cu12-11.3.0.4 nvidia-cufile-cu12-1.11.1.6 nvidia-curand-cu12-10.3.7.77 nvidia-cusolver-cu12-11.7.1.2 nvidia-cusparse-cu12-12.5.4.2 nvidia-cusparselt-cu12-0.6.3 nvidia-nccl-cu12-2.26.2 nvidia-nvjitlink-cu12-12.6.85 nvidia-nvtx-cu12-12.6.77 safetensors-0.5.3 scikit-learn-1.6.1 sentence-transformers-4.1.0 threadpoolctl-3.6.0 torch-2.7.0 transformers-4.51.3 triton-3.3.0
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.4k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# array([[-0.05405934, -0.01718493, -0.03553742, ...,  0.02126809,
#          0.04306812, -0.0107799 ],
#        [-0.06346931, -0.0316185 , -0.01481563, ...,  0.03250144,
#         -0.02075411,  0.00200078],
#        [-0.03902554,  0.03801628,  0.00174587, ..., -0.01257586,
#         -0.05982951, -0.04102634]], dtype=float32)

# %%
class CoffeeRAG:
    def __init__(self):
        self.mongo = MongoConnectionHandler()
        self.processor = DocumentProcessor()
        self.vector_store = VectorStore()
        self.llm = OllamaLLM(model="gemma3")
        
        self.prompt = ChatPromptTemplate.from_template(
            """As a coffee order analyst, answer using this context:
            Today: {current_date}
            Context:
            {context}
            
            Question: {question}
            
            Format response with appropriately
            And if no answer is available respond with "Answer not found, contact our support personal via hello@arkenacoffee.com" """
        )
    
    def initialize(self):
        """Load data from MongoDB and index it"""
        data = self.mongo.get_related_documents()
        chunks = self.processor.create_chunks(data)
        self.vector_store.index_documents(chunks)
    
    def retrieve(self, query: str) -> List[Dict]:
        return self.vector_store.query(query)
    
    def generate(self, query: str) -> str:
        context = self.retrieve(query)
        print(f"Context extracted: {context}")
        context_str = "\n\n---\n\n".join([f"{r['text']}\nMetadata: {r['metadata']}" for r in context])
        
        chain = (
            {"context": lambda _: context_str,
             "question": RunnablePassthrough(),
             "current_date": lambda _: datetime.now().strftime("%Y-%m-%d %H:%M")}
            | self.prompt
            | self.llm
            | StrOutputParser()
        )
        return chain.invoke(query)

# %%
if __name__ == "__main__":
    # Initialize components
    processor = DocumentProcessor()
    rag = CoffeeRAG()
    
    # Load and process data (run once)
    raw_data = MongoConnectionHandler().get_related_documents()
    chunks = processor.create_chunks(raw_data)
    rag.vector_store.index_documents(chunks)
    
    # Example queries
    queries = [
        "Which client has the most Completed order?"
    ]
    
    for query in queries:
        print(f"\nQuery: {query}")
        print("Answer:")
        print(rag.generate(query))
        print("\n" + "="*50)
# Out:
# Query: Find orders where the company is based in the US
# Answer:
# Context extracted: [{'text': '[Order 65d238d4acb24b003b6733a4] = Status: "CANCELLED" , Created Date: "Date not available" , Contract: "N/A" | [Client 65c22c47b062b6003c932497] = Company: "Cafe Kreyol, LLC" , Client Name: "Joseph Stazzone" , Email: "joey@cafekreyol.com" , Company Address: "10439 Balls Ford Road" Company City: "Manassas" Preferences: (Natural, Washed, Honey, Anerobic, Carbonic Maceration) | [Items] = Item 1 ID: "2-OrdIt1" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 2 ID: "2-OrdIt0" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 3 ID: "2-OrdIt2" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available",', 'metadata': {'total_value': 0, 'client_name': 'Joseph Stazzone', 'client_id': '65c22c47b062b6003c932497', 'status': 'CANCELLED', 'order_id': '65d238d4acb24b003b6733a4', 'creation_date': '2024-02-18 17:05:25.107000'}}, {'text': '[Order 65d238d4acb24b003b6733a4] = Status: "CANCELLED" , Created Date: "Date not available" , Contract: "N/A" | [Client 65c22c47b062b6003c932497] = Company: "Cafe Kreyol, LLC" , Client Name: "Joseph Stazzone" , Email: "joey@cafekreyol.com" , Company Address: "10439 Balls Ford Road" Company City: "Manassas" Preferences: (Natural, Washed, Honey, Anerobic, Carbonic Maceration) | [Items] = Item 1 ID: "2-OrdIt1" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 2 ID: "2-OrdIt0" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 3 ID: "2-OrdIt2" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available",', 'metadata': {'total_value': 0, 'creation_date': '2024-02-18 17:05:25.107000', 'status': 'CANCELLED', 'client_name': 'Joseph Stazzone', 'order_id': '65d238d4acb24b003b6733a4', 'client_id': '65c22c47b062b6003c932497'}}, {'text': '[Order 65d238d4acb24b003b6733a4] = Status: "CANCELLED" , Created Date: "Date not available" , Contract: "N/A" | [Client 65c22c47b062b6003c932497] = Company: "Cafe Kreyol, LLC" , Client Name: "Joseph Stazzone" , Email: "joey@cafekreyol.com" , Company Address: "10439 Balls Ford Road" Company City: "Manassas" Preferences: (Natural, Washed, Honey, Anerobic, Carbonic Maceration) | [Items] = Item 1 ID: "2-OrdIt1" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 2 ID: "2-OrdIt0" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 3 ID: "2-OrdIt2" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available",', 'metadata': {'status': 'CANCELLED', 'order_id': '65d238d4acb24b003b6733a4', 'total_value': 0, 'client_id': '65c22c47b062b6003c932497', 'creation_date': '2024-02-18 17:05:25.107000', 'client_name': 'Joseph Stazzone'}}, {'text': '[Order 65d238d4acb24b003b6733a4] = Status: "CANCELLED" , Created Date: "Date not available" , Contract: "N/A" | [Client 65c22c47b062b6003c932497] = Company: "Cafe Kreyol, LLC" , Client Name: "Joseph Stazzone" , Email: "joey@cafekreyol.com" , Company Address: "10439 Balls Ford Road" Company City: "Manassas" Preferences: (Natural, Washed, Honey, Anerobic, Carbonic Maceration) | [Items] = Item 1 ID: "2-OrdIt1" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 2 ID: "2-OrdIt0" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available", Item 3 ID: "2-OrdIt2" , Total Amount: "0lbs" , Price: "$0" , Status: "REJECTED" , Last Updated: "Date not available",', 'metadata': {'status': 'CANCELLED', 'order_id': '65d238d4acb24b003b6733a4', 'client_name': 'Joseph Stazzone', 'total_value': 0, 'client_id': '65c22c47b062b6003c932497', 'creation_date': '2024-02-18 17:05:25.107000'}}, {'text': '[Order 67c04f18074f4300344156ce] = Status: "PROCESSING" , Created Date: "Date  ...
# ```json
# [
#   {
#     "order_id": "65cdf655acb24b003b673350",
#     "company": "Cafe Kreyol, LLC",
#     "company_location": "10439 Balls Ford Road, Manassas"
#   }
# ]
# ```
#
# ==================================================
